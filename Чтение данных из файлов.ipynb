# %%
import pandas as pd

# %% [markdown]
# #### Загрузка данных из тестового файла (CSV)

# %%
df_p=pd.read_csv('C:/Users/Пользователь/Desktop/Python/Pandas_ данные для курса/Products.csv', sep=';')

# %%
df_p
# Out:
#     ProductID                      ProductName  Product_Description  \
# 0           1                             Chai   10 boxes x 20 bags
# 1           2                            Chang   24 - 12 oz bottles
# 2           3                    Aniseed Syrup  12 - 550 ml bottles
# 3           4     Chef Anton's Cajun Seasoning       48 - 6 oz jars
# 4           5           Chef Anton's Gumbo Mix             36 boxes
# ..        ...                              ...                  ...
# 72         73                       Rod Kaviar      24 - 150 g jars
# 73         74                    Longlife Tofu            5 kg pkg.
# 74         75             Rhonbrau Klosterbier   24 - 0.5 l bottles
# 75         76                     Lakkalikoori               500 ml
# 76         77  Original Frankfurter gr?ne Sobe             12 boxes
#
#     UnitPrice  CategoryID CategoryName  \
# 0       18.00           1    Beverages
# 1       19.00           1    Beverages
# ...

# %%
df_p.shape[0]
# Out:
# 77

# %%
len(df_p)
# Out:
# 77

# %%
type(df_p)
# Out:
# pandas.core.frame.DataFrame

# %%
df_p.dtypes
# Out:
# ProductID                 int64
# ProductName              object
# Product_Description      object
# UnitPrice               float64
# CategoryID                int64
# CategoryName             object
# Category_Description     object
# dtype: object

# %%
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductID             77 non-null     int64
#  1   ProductName           77 non-null     object
#  2   Product_Description   77 non-null     object
#  3   UnitPrice             77 non-null     float64
#  4   CategoryID            77 non-null     int64
#  5   CategoryName          77 non-null     object
#  6   Category_Description  77 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 4.3+ KB

# %%
df_p.head(10)
# Out:
#    ProductID                      ProductName  Product_Description  UnitPrice  \
# 0          1                             Chai   10 boxes x 20 bags      18.00
# 1          2                            Chang   24 - 12 oz bottles      19.00
# 2          3                    Aniseed Syrup  12 - 550 ml bottles      10.00
# 3          4     Chef Anton's Cajun Seasoning       48 - 6 oz jars      22.00
# 4          5           Chef Anton's Gumbo Mix             36 boxes      21.35
# 5          6     Grandma's Boysenberry Spread       12 - 8 oz jars      25.00
# 6          7  Uncle Bob's Organic Dried Pears      12 - 1 lb pkgs.      30.00
# 7          8       Northwoods Cranberry Sauce      12 - 12 oz jars      40.00
# 8          9                  Mishi Kobe Niku     18 - 500 g pkgs.      97.00
# 9         10                            Ikura     12 - 200 ml jars      31.00
#
#    CategoryID  CategoryName                               Category_Description
# ...

# %%
# Получить нижние 10 строк
df_p.tail(10)
# Out:
#     ProductID                      ProductName  Product_Description  \
# 67         68              Scottish Longbreads  10 boxes x 8 pieces
# 68         69                 Gudbrandsdalsost           10 kg pkg.
# 69         70                    Outback Lager  24 - 355 ml bottles
# 70         71                      Flotemysost     10 - 500 g pkgs.
# 71         72           Mozzarella di Giovanni     24 - 200 g pkgs.
# 72         73                       Rod Kaviar      24 - 150 g jars
# 73         74                    Longlife Tofu            5 kg pkg.
# 74         75             Rhonbrau Klosterbier   24 - 0.5 l bottles
# 75         76                     Lakkalikoori               500 ml
# 76         77  Original Frankfurter gr?ne Sobe             12 boxes
#
#     UnitPrice  CategoryID    CategoryName  \
# 67      12.50           3     Confections
# 68      36.00           4  Dairy Products
# 69      15.00           1       Beverages
# 70      21.50           4  Dairy Products
# ...

# %%
df_c=pd.read_csv('C:/Users/Пользователь/Desktop/Python/Pandas_ данные для курса/Customers.csv', sep=';', header = None)

# %%
df_c
# Out:
#              0                        1                          2  \
# 0   CustomerID              ContactName               ContactTitle
# 1        ALFKI             Maria Anders       Sales Representative
# 2        ANATR             Ana Trujillo                      Owner
# 3        ANTON           Antonio Moreno                      Owner
# 4        AROUT             Thomas Hardy       Sales Representative
# ..         ...                      ...                        ...
# 87       WARTH         Pirkko Koskitalo         Accounting Manager
# 88       WELLI            Paula Parente              Sales Manager
# 89       WHITC           Karl Jablonski                      Owner
# 90       WILMK          Matti Karttunen  Owner/Marketing Assistant
# 91       WOLZA  Zbyszek Piestrzeniewicz                      Owner
#
#                  3                              4
# 0            Phone                        Address
# 1      030-0074321                  Obere Str. 57
# ...

# %%
df_c.head(26)
# Out:
#              0                   1                      2               3  \
# 0   CustomerID         ContactName           ContactTitle           Phone
# 1        ALFKI        Maria Anders   Sales Representative     030-0074321
# 2        ANATR        Ana Trujillo                  Owner    (5) 555-4729
# 3        ANTON      Antonio Moreno                  Owner    (5) 555-3932
# 4        AROUT        Thomas Hardy   Sales Representative  (171) 555-7788
# 5        BERGS  Christina Berglund    Order Administrator   0921-12 34 65
# 6        BLAUS          Hanna Moos   Sales Representative      0621-08460
# 7        BLONP  Frederique Citeaux      Marketing Manager     88.60.15.31
# 8        BOLID       Martin Sommer                  Owner  (91) 555 22 82
# 9        BONAP    Laurence Lebihan                  Owner     91.24.45.40
# 10       BOTTM   Elizabeth Lincoln     Accounting Manager  (604) 555-4729
# 11       BSBEV   Victoria Ashworth   Sales Representative  (171) 555-1212
# ...

# %%
df_o = pd.read_csv('C:/Users/Пользователь/Desktop/Python/Pandas_ данные для курса/Orders.csv', sep=';')

# %%
df_o
# Out:
#      OrderID CustomerID  EmployeeID                OrderDate  \
# 0      10248      VINET           5  1996-07-04 00:00:00.000
# 1      10249      TOMSP           6  1996-07-05 00:00:00.000
# 2      10250      HANAR           4  1996-07-08 00:00:00.000
# 3      10251      VICTE           3  1996-07-08 00:00:00.000
# 4      10252      SUPRD           4  1996-07-09 00:00:00.000
# ..       ...        ...         ...                      ...
# 825    11073      PERIC           2  1998-05-05 00:00:00.000
# 826    11074      SIMOB           7  1998-05-06 00:00:00.000
# 827    11075      RICSU           8  1998-05-06 00:00:00.000
# 828    11076      BONAP           4  1998-05-06 00:00:00.000
# 829    11077      RATTC           1  1998-05-06 00:00:00.000
#
#                 RequiredDate              ShippedDate  Freight
# 0    1996-08-01 00:00:00.000  1996-07-16 00:00:00.000    32.38
# 1    1996-08-16 00:00:00.000  1996-07-10 00:00:00.000    11.61
# ...

# %%
df_o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       830 non-null    int64
#  1   CustomerID    830 non-null    object
#  2   EmployeeID    830 non-null    int64
#  3   OrderDate     830 non-null    object
#  4   RequiredDate  830 non-null    object
#  5   ShippedDate   809 non-null    object
#  6   Freight       830 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 45.5+ KB

# %%
df_od = pd.read_csv('C:/Users/Пользователь/Desktop/Python/Pandas_ данные для курса/Order_details.csv', sep=';')

# %%
df_od
# Out:
#       OrderID  ProductID  UnitPrice  Quantity  Discount
# 0       10248         11      14.00        12      0.00
# 1       10248         42       9.80        10      0.00
# 2       10248         72      34.80         5      0.00
# 3       10249         14      18.60         9      0.00
# 4       10249         51      42.40        40      0.00
# ...       ...        ...        ...       ...       ...
# 2150    11077         64      33.25         2      0.03
# 2151    11077         66      17.00         1      0.00
# 2152    11077         73      15.00         2      0.01
# 2153    11077         75       7.75         4      0.00
# 2154    11077         77      13.00         2      0.00
#
# [2155 rows x 5 columns]

# %% [markdown]
# #### Загрузка данных из Excel

# %%
df_e = pd.read_excel('C:/Users/Пользователь/Desktop/Python/Pandas_ данные для курса/Employees.xlsx')

# %%
df_e
# Out:
#    EmployeeID FirstName   LastName                     Title TitleOfCourtesy  \
# 0           1     Nancy    Davolio      Sales Representative             Ms.
# 1           2    Andrew     Fuller     Vice President, Sales             Dr.
# 2           3     Janet  Leverling      Sales Representative             Ms.
# 3           4  Margaret    Peacock      Sales Representative            Mrs.
# 4           5    Steven   Buchanan             Sales Manager             Mr.
# 5           6   Michael     Suyama      Sales Representative             Mr.
# 6           7    Robert       King      Sales Representative             Mr.
# 7           8     Laura   Callahan  Inside Sales Coordinator             Ms.
# 8           9      Anne  Dodsworth      Sales Representative             Ms.
#
#                  BirthDate                 HireDate  \
# 0  1948-12-08 00:00:00.000  1992-05-01 00:00:00.000
# 1  1952-02-19 00:00:00.000  1992-08-14 00:00:00.000
# ...

# %%
df_e = pd.read_excel('C:/Users/Пользователь/Desktop/Python/Pandas_ данные для курса/Employees.xlsx', header = None, sheet_name = 'Лист2')

# %%
df_e
# Out:
#       0
# 0  тест
# 1  тест

# %%
df_e = pd.read_excel('C:/Users/Пользователь/Desktop/Python/Pandas_ данные для курса/Employees.xlsx', sheet_name = 'Лист3')

# %%
# Позволяет получить базовые статистические показатели
df_e.describe()
# Out:
#          Возраст
# count  32.000000
# mean   42.750000
# std    12.373228
# min    21.000000
# 25%    32.750000
# 50%    41.500000
# 75%    51.250000
# max    68.000000
